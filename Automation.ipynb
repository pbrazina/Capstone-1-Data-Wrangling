# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

#css styling for tables
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
df = pd.read_csv('https://query.data.world/s/srihmhagj7m7el6hdbzoo7boiqkyy2', engine='python', index_col=0)

df.head()
# Out:
#                                   Occupation  Probability  Alabama  Alaska  \
# SOC
# 11-1011                     Chief Executives        0.015     1030     760
# 11-1021      General and Operations Managers        0.160    26930    6490
# 11-2011  Advertising and Promotions Managers        0.039       50      40
# 11-2021                   Marketing Managers        0.014      530     200
# 11-2022                       Sales Managers        0.013     2510     400
#
#          Arizona  Arkansas  California  Colorado  Connecticut  Delaware  \
# SOC
# 11-1011     5750      2710       31150       880         1410       340
# 11-1021    43300     20680      261780     41540        33280      4080
# 11-2011      470       110        3760       480          300         0
# 11-2021     4790      1090       33390      3060         4970       590
# 11-2022    10650      2650       69180      4570         7040       860
#
# ...

# %%
df = pd.read_csv('automation.csv')
df.head()
# Out:
#        SOC                           Occupation  Probability  Alabama  Alaska  \
# 0  11-1011                     Chief Executives        0.015     1030     760
# 1  11-1021      General and Operations Managers        0.160    26930    6490
# 2  11-2011  Advertising and Promotions Managers        0.039       50      40
# 3  11-2021                   Marketing Managers        0.014      530     200
# 4  11-2022                       Sales Managers        0.013     2510     400
#
#    Arizona  Arkansas  California  Colorado  Connecticut   ...     \
# 0     5750      2710       31150       880         1410   ...
# 1    43300     20680      261780     41540        33280   ...
# 2      470       110        3760       480          300   ...
# 3     4790      1090       33390      3060         4970   ...
# 4    10650      2650       69180      4570         7040   ...
#
#    South Dakota  Tennessee   Texas   Utah  Vermont  Virginia  Washington  \
# ...

# %%
df2 = df
df2.set_index(['Occupation', 'Probability', 'SOC'], inplace=True)
df2
# Out:
#                                                                         Alabama  \
# Occupation                                         Probability SOC
# Chief Executives                                   0.0150      11-1011     1030
# General and Operations Managers                    0.1600      11-1021    26930
# Advertising and Promotions Managers                0.0390      11-2011       50
# Marketing Managers                                 0.0140      11-2021      530
# Sales Managers                                     0.0130      11-2022     2510
# Public Relations and Fundraising Managers          0.0150      11-2031      400
# Administrative Services Managers                   0.7300      11-3011      640
# Computer and Information Systems Managers          0.0350      11-3021     3260
# Financial Managers                                 0.0690      11-3031     4990
# Industrial Production Managers                     0.0300      11-3051     3110
# ...

# %%
df.columns
# Out:
# Index(['SOC', 'Occupation', 'Probability', 'Alabama', 'Alaska', 'Arizona',
#        'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object')

# %%
#reorganizing the data for easy visual access
num = df[['Alabama', 'Alaska', 'Arizona',
       'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware',
       'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
       'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
       'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
       'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
       'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
       'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
       'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
       'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
       'West Virginia', 'Wisconsin', 'Wyoming']]

occupation_totals = num.sum(axis=1)
num['US_Totals'] = occupation_totals

state_totals = num.sum(axis=0)
state_totals['US_Totals'] = occupation_totals.sum()

num.index = [df.Occupation, df.Probability]


#num = num.append(state_totals, ignore_index=True)

state_totals
# Out:
# C:\Python\lib\site-packages\ipykernel\__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Alabama                   1722020
# Alaska                     284920
# Arizona                   2355040
# Arkansas                  1070380
# California               14163090
# Colorado                  2212180
# Connecticut               1475400
# Delaware                   371070
# District of Columbia       599560
# Florida                   7349340
# Georgia                   3797560
# Hawaii                     558070
# Idaho                      589520
# Illinois                  5168630
# Indiana                   2684160
# Iowa                      1363960
# Kansas                    1216310
# Kentucky                  1650310
# ...

# %%
num.query('Probability > .89').query('US_Totals > 100000').sort_values('US_Totals', ascending = False)
# Out:
#                                                                           Alabama  \
# Occupation                                         Probability US_Totals
# Retail Salespersons                                0.92        4528570      59690
# Cashiers                                           0.97        3540980      72610
# Combined Food Preparation and Serving Workers; ... 0.92        3426090      49320
# Office Clerks; General                             0.96        2955560      32610
# Waiters and Waitresses                             0.94        2564620      32420
# Secretaries and Administrative Assistants; Exce... 0.96        2295480      45760
# Bookkeeping; Accounting; and Auditing Clerks       0.98        1566970      22190
# Accountants and Auditors                           0.94        1246530      15360
# Cooks; Restaurant                                  0.96        1217360      15790
# ...
